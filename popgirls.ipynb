# %%
import geopandas as gpd
import contextily as ctx
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt

# set font
import matplotlib as mpl

# for Mac
mpl.rc('font',family='Hiragino Maru Gothic Pro')

# for PC
# mpl.rc('font',family='MS Gothic')

# %%
gdf = gpd.read_file('data/A002005212010DDSWC12')

# %%
# explore the data
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6488 entries, 0 to 6487
# Data columns (total 44 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    6488 non-null   object
#  1   PREF        6488 non-null   object
#  2   CITY        6488 non-null   object
#  3   S_AREA      6488 non-null   object
#  4   PREF_NAME   6488 non-null   object
#  5   CITY_NAME   6488 non-null   object
#  6   S_NAME      6486 non-null   object
#  7   KIGO_E      1004 non-null   object
#  8   HCODE       6488 non-null   int64
#  9   AREA        6488 non-null   float64
#  10  PERIMETER   6488 non-null   float64
#  11  H22KAxx#    6488 non-null   int64
#  12  H22KAxx-ID  6488 non-null   int64
#  13  KEN         6488 non-null   object
#  14  KEN_NAME    6488 non-null   object
#  15  SITYO_NAME  0 non-null      float64
#  16  GST_NAME    6488 non-null   object
#  17  CSS_NAME    1220 non-null   object
# ...

# %%
gdf.head()
# Out:
#       KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME  S_NAME KIGO_E  HCODE
# 0    121010010   12  101  001000       千葉県       中央区     青葉町    NaN   8101  \
# 1    121010020   12  101  002000       千葉県       中央区     赤井町    NaN   8101
# 2    121010030   12  101  003000       千葉県       中央区      旭町    NaN   8101
# 3    121010040   12  101  004000       千葉県       中央区     市場町    NaN   8101
# 4  12101005001   12  101  005001       千葉県       中央区  稲荷町１丁目    NaN   8101
#
#          AREA  ...    MOJI  SEQ_NO2  KSUM CSUM JINKO  SETAI     X_CODE
# 0   842597.00  ...     青葉町     4309    39   44  2848    971  140.13982  \
# 1  1378185.00  ...     赤井町     4400    17   17  1419    464  140.16127
# 2   102830.60  ...      旭町     4275    30   30   959    503  140.13423
# 3   124328.80  ...     市場町     4295    11   12   421    228  140.12500
# 4    71919.35  ...  稲荷町１丁目     4352    16   16   684    283  140.12495
#
#      Y_CODE   KCODE1                                           geometry
# ...

# %%
ax = gdf.plot()

# %%
df=pd.read_csv('data/tblT000614C12.txt',encoding='cp932')

# %%
gdf.head()
# Out:
#       KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME  S_NAME KIGO_E  HCODE
# 0    121010010   12  101  001000       千葉県       中央区     青葉町    NaN   8101  \
# 1    121010020   12  101  002000       千葉県       中央区     赤井町    NaN   8101
# 2    121010030   12  101  003000       千葉県       中央区      旭町    NaN   8101
# 3    121010040   12  101  004000       千葉県       中央区     市場町    NaN   8101
# 4  12101005001   12  101  005001       千葉県       中央区  稲荷町１丁目    NaN   8101
#
#          AREA  ...    MOJI  SEQ_NO2  KSUM CSUM JINKO  SETAI     X_CODE
# 0   842597.00  ...     青葉町     4309    39   44  2848    971  140.13982  \
# 1  1378185.00  ...     赤井町     4400    17   17  1419    464  140.16127
# 2   102830.60  ...      旭町     4275    30   30   959    503  140.13423
# 3   124328.80  ...     市場町     4295    11   12   421    228  140.12500
# 4    71919.35  ...  稲荷町１丁目     4352    16   16   684    283  140.12495
#
#      Y_CODE   KCODE1                                           geometry
# ...

# %%
df.head()
# Out:
#       KEY_CODE  HYOSYO CITYNAME NAME  HTKSYORI  HTKSAKI GASSAN T000614001
# 0          NaN     NaN      NaN  NaN       NaN      NaN    NaN     総数（職業）  \
# 1  121010010.0     2.0   千葉市中央区  青葉町       0.0      NaN    NaN       1239
# 2  121010020.0     2.0   千葉市中央区  赤井町       0.0      NaN    NaN        572
# 3  121010030.0     2.0   千葉市中央区   旭町       0.0      NaN    NaN        424
# 4  121010040.0     2.0   千葉市中央区  市場町       0.0      NaN    NaN        209
#
#    T000614002      T000614003 T000614004 T000614005   T000614006 T000614007
# 0  Ａ 管理的職業従事者  Ｂ 専門的・技術的職業従事者    Ｃ 事務従事者    Ｄ 販売従事者  Ｅ サービス職業従事者  Ｆ 保安職業従事者  \
# 1          43             386        374        146           77         18
# 2           6              80        107         76           69          9
# 3          16              72         72         70           59          5
# 4          12              43         35         43           28          3
#
# ...

# %%
df['T000614001']=pd.to_numeric(df['T000614001'],errors='coerce')
df['T000614002']=pd.to_numeric(df['T000614002'],errors='coerce')
df['T000614003']=pd.to_numeric(df['T000614003'],errors='coerce')
df['T000614004']=pd.to_numeric(df['T000614004'],errors='coerce')
df['T000614005']=pd.to_numeric(df['T000614005'],errors='coerce')
df['T000614006']=pd.to_numeric(df['T000614006'],errors='coerce')
df['T000614007']=pd.to_numeric(df['T000614007'],errors='coerce')
df['T000614008']=pd.to_numeric(df['T000614008'],errors='coerce')
df['T000614009']=pd.to_numeric(df['T000614009'],errors='coerce')
df['T000614010']=pd.to_numeric(df['T000614010'],errors='coerce')
df['T000614011']=pd.to_numeric(df['T000614011'],errors='coerce')
df['T000614012']=pd.to_numeric(df['T000614012'],errors='coerce')
df['T000614013']=pd.to_numeric(df['T000614013'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    6542 non-null   float64
#  1   HYOSYO      6542 non-null   float64
#  2   CITYNAME    6542 non-null   object
#  3   NAME        6540 non-null   object
#  4   HTKSYORI    6542 non-null   float64
#  5   HTKSAKI     70 non-null     float64
#  6   GASSAN      55 non-null     object
#  7   T000614001  6300 non-null   float64
#  8   T000614002  5654 non-null   float64
#  9   T000614003  6224 non-null   float64
#  10  T000614004  6269 non-null   float64
#  11  T000614005  6236 non-null   float64
#  12  T000614006  6248 non-null   float64
#  13  T000614007  5708 non-null   float64
#  14  T000614008  5372 non-null   float64
#  15  T000614009  6257 non-null   float64
#  16  T000614010  6098 non-null   float64
#  17  T000614011  6097 non-null   float64
# ...

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6488 entries, 0 to 6487
# Data columns (total 44 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    6488 non-null   object
#  1   PREF        6488 non-null   object
#  2   CITY        6488 non-null   object
#  3   S_AREA      6488 non-null   object
#  4   PREF_NAME   6488 non-null   object
#  5   CITY_NAME   6488 non-null   object
#  6   S_NAME      6486 non-null   object
#  7   KIGO_E      1004 non-null   object
#  8   HCODE       6488 non-null   int64
#  9   AREA        6488 non-null   float64
#  10  PERIMETER   6488 non-null   float64
#  11  H22KAxx#    6488 non-null   int64
#  12  H22KAxx-ID  6488 non-null   int64
#  13  KEN         6488 non-null   object
#  14  KEN_NAME    6488 non-null   object
#  15  SITYO_NAME  0 non-null      float64
#  16  GST_NAME    6488 non-null   object
#  17  CSS_NAME    1220 non-null   object
# ...

# %%
gdf['KEY_CODE']=gdf['KEY_CODE'].astype(float)

# %%
gdf=gdf.merge(df,on='KEY_CODE')

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6488 entries, 0 to 6487
# Data columns (total 63 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    6488 non-null   float64
#  1   PREF        6488 non-null   object
#  2   CITY        6488 non-null   object
#  3   S_AREA      6488 non-null   object
#  4   PREF_NAME   6488 non-null   object
#  5   CITY_NAME   6488 non-null   object
#  6   S_NAME      6486 non-null   object
#  7   KIGO_E      1004 non-null   object
#  8   HCODE       6488 non-null   int64
#  9   AREA        6488 non-null   float64
#  10  PERIMETER   6488 non-null   float64
#  11  H22KAxx#    6488 non-null   int64
#  12  H22KAxx-ID  6488 non-null   int64
#  13  KEN         6488 non-null   object
#  14  KEN_NAME    6488 non-null   object
#  15  SITYO_NAME  0 non-null      float64
#  16  GST_NAME    6488 non-null   object
#  17  CSS_NAME    1220 non-null   object
# ...

# %%
gdf.head()
# Out:
#        KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME  S_NAME KIGO_E  HCODE
# 0  1.210100e+08   12  101  001000       千葉県       中央区     青葉町    NaN   8101  \
# 1  1.210100e+08   12  101  002000       千葉県       中央区     赤井町    NaN   8101
# 2  1.210100e+08   12  101  003000       千葉県       中央区      旭町    NaN   8101
# 3  1.210100e+08   12  101  004000       千葉県       中央区     市場町    NaN   8101
# 4  1.210101e+10   12  101  005001       千葉県       中央区  稲荷町１丁目    NaN   8101
#
#          AREA  ...  T000614004  T000614005  T000614006 T000614007 T000614008
# 0   842597.00  ...       374.0       146.0        77.0       18.0        3.0  \
# 1  1378185.00  ...       107.0        76.0        69.0        9.0       15.0
# 2   102830.60  ...        72.0        70.0        59.0        5.0        4.0
# 3   124328.80  ...        35.0        43.0        28.0        3.0        NaN
# 4    71919.35  ...        59.0        50.0        35.0        5.0        1.0
#
# ...

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6488 entries, 0 to 6487
# Data columns (total 63 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    6488 non-null   float64
#  1   PREF        6488 non-null   object
#  2   CITY        6488 non-null   object
#  3   S_AREA      6488 non-null   object
#  4   PREF_NAME   6488 non-null   object
#  5   CITY_NAME   6488 non-null   object
#  6   S_NAME      6486 non-null   object
#  7   KIGO_E      1004 non-null   object
#  8   HCODE       6488 non-null   int64
#  9   AREA        6488 non-null   float64
#  10  PERIMETER   6488 non-null   float64
#  11  H22KAxx#    6488 non-null   int64
#  12  H22KAxx-ID  6488 non-null   int64
#  13  KEN         6488 non-null   object
#  14  KEN_NAME    6488 non-null   object
#  15  SITYO_NAME  0 non-null      float64
#  16  GST_NAME    6488 non-null   object
#  17  CSS_NAME    1220 non-null   object
# ...

# %%
fig,ax= plt.subplots(figsize=(12,12))

gdf.plot(ax=ax,
          column='T000614004',
          legend=True,
          vmax= 350,
         )
# title
ax.set_title('2010 事務従事者',fontsize=24, pad=20);
# hide axes
ax.axis('off')
# Out:
# (139.69708867759886, 140.92903977523576, 34.83887417537006, 36.164364999024066)

# %% [markdown]
# My team pop girsls is doing a presentation on labor force change in Chiba over the years. My role is to download data and make a map on Chiba labour force in 2010. With the help of the teacher, we came to a conlusion to add some charts and graphs in our presentaion too. I think it is a very interesting topic to make a map about.
