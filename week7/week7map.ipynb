# %%
import geopandas as gpd
import pandas as pd

# %%
hokkaido = gpd.read_file('N03-23_01_230101.geojson')

# %%
hokkaido.plot()
# Out:
# <Axes: >

# %%
hokkaido.head()
# Out:
#   N03_001 N03_002 N03_003 N03_004 N03_007
# 0     北海道   石狩振興局     札幌市  札幌市中央区   01101  \
# 1     北海道   石狩振興局     札幌市   札幌市北区   01102
# 2     北海道   石狩振興局     札幌市   札幌市東区   01103
# 3     北海道   石狩振興局     札幌市  札幌市白石区   01104
# 4     北海道   石狩振興局     札幌市  札幌市豊平区   01105
#
#                                             geometry
# 0  POLYGON ((141.34233 43.06682, 141.34285 43.066...
# 1  POLYGON ((141.40839 43.18395, 141.40833 43.183...
# 2  POLYGON ((141.44707 43.15616, 141.44694 43.155...
# 3  POLYGON ((141.46244 43.10010, 141.46265 43.100...
# 4  POLYGON ((141.38463 43.04670, 141.38479 43.046...

# %%
hokkaido.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9575 entries, 0 to 9574
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   9575 non-null   object
#  1   N03_002   9575 non-null   object
#  2   N03_003   7141 non-null   object
#  3   N03_004   9575 non-null   object
#  4   N03_007   9575 non-null   object
#  5   geometry  9575 non-null   geometry
# dtypes: geometry(1), object(5)
# memory usage: 449.0+ KB

# %%
hokkaido_pop = pd.read_csv('Hokkaido.csv')

# %%
hokkaido_pop.head()
# Out:
#    KEY_CODE  HYOSYO CITYNAME      NAME  HTKSYORI  HTKSAKI  GASSAN    人口総数
# 0      1101       1   札幌市中央区       NaN         0      NaN     NaN  248680  \
# 1  11010200       2   札幌市中央区   宮ケ丘（番地）         0      NaN     NaN       5
# 2  11010300       2   札幌市中央区        円山         0      NaN     NaN       -
# 3  11010400       2   札幌市中央区  円山西町（番地）         0      NaN     NaN       -
# 4  11011000       2   札幌市中央区       宮の森         0      NaN     NaN     456
#
#         男       女    世帯総数
# 0  112853  135827  141429
# 1       2       3       2
# 2       -       -       -
# 3       -       -       -
# 4      91     365      18

# %%
hokkaido_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25699 entries, 0 to 25698
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  25699 non-null  int64
#  1   HYOSYO    25699 non-null  int64
#  2   CITYNAME  25699 non-null  object
#  3   NAME      25511 non-null  object
#  4   HTKSYORI  25699 non-null  int64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      25699 non-null  object
#  8   男         25699 non-null  object
#  9   女         25699 non-null  object
#  10  世帯総数      25699 non-null  object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 2.2+ MB

# %%
hokkaido.rename(columns={'N03_007':'KEY_CODE'},inplace=True)

# %%
hokkaido
# Out:
#      N03_001 N03_002 N03_003 N03_004 KEY_CODE
# 0        北海道   石狩振興局     札幌市  札幌市中央区    01101  \
# 1        北海道   石狩振興局     札幌市   札幌市北区    01102
# 2        北海道   石狩振興局     札幌市   札幌市東区    01103
# 3        北海道   石狩振興局     札幌市  札幌市白石区    01104
# 4        北海道   石狩振興局     札幌市  札幌市豊平区    01105
# ...      ...     ...     ...     ...      ...
# 9570     北海道   根室振興局     蘂取郡     蘂取村    01700
# 9571     北海道   根室振興局     蘂取郡     蘂取村    01700
# 9572     北海道   根室振興局     蘂取郡     蘂取村    01700
# 9573     北海道   根室振興局     蘂取郡     蘂取村    01700
# 9574     北海道   根室振興局     蘂取郡     蘂取村    01700
#
#                                                geometry
# 0     POLYGON ((141.34233 43.06682, 141.34285 43.066...
# 1     POLYGON ((141.40839 43.18395, 141.40833 43.183...
# 2     POLYGON ((141.44707 43.15616, 141.44694 43.155...
# 3     POLYGON ((141.46244 43.10010, 141.46265 43.100...
# 4     POLYGON ((141.38463 43.04670, 141.38479 43.046...
# ...                                                 ...
# ...

# %%
hokkaido['KEY_CODE'] = hokkaido['KEY_CODE'].astype(int)

# %%
hokkaido.info
# Out:
# <bound method DataFrame.info of      N03_001 N03_002 N03_003 N03_004  KEY_CODE
# 0        北海道   石狩振興局     札幌市  札幌市中央区      1101  \
# 1        北海道   石狩振興局     札幌市   札幌市北区      1102
# 2        北海道   石狩振興局     札幌市   札幌市東区      1103
# 3        北海道   石狩振興局     札幌市  札幌市白石区      1104
# 4        北海道   石狩振興局     札幌市  札幌市豊平区      1105
# ...      ...     ...     ...     ...       ...
# 9570     北海道   根室振興局     蘂取郡     蘂取村      1700
# 9571     北海道   根室振興局     蘂取郡     蘂取村      1700
# 9572     北海道   根室振興局     蘂取郡     蘂取村      1700
# 9573     北海道   根室振興局     蘂取郡     蘂取村      1700
# 9574     北海道   根室振興局     蘂取郡     蘂取村      1700
#
#                                                geometry
# 0     POLYGON ((141.34233 43.06682, 141.34285 43.066...
# 1     POLYGON ((141.40839 43.18395, 141.40833 43.183...
# 2     POLYGON ((141.44707 43.15616, 141.44694 43.155...
# 3     POLYGON ((141.46244 43.10010, 141.46265 43.100...
# 4     POLYGON ((141.38463 43.04670, 141.38479 43.046...
# ...

# %%
hokkaido_pop = hokkaido.merge(hokkaido_pop,on='KEY_CODE')

# %%
hokkaido_pop
# Out:
#      N03_001 N03_002 N03_003 N03_004  KEY_CODE
# 0        北海道   石狩振興局     札幌市  札幌市中央区      1101  \
# 1        北海道   石狩振興局     札幌市   札幌市北区      1102
# 2        北海道   石狩振興局     札幌市   札幌市東区      1103
# 3        北海道   石狩振興局     札幌市  札幌市白石区      1104
# 4        北海道   石狩振興局     札幌市  札幌市豊平区      1105
# ...      ...     ...     ...     ...       ...
# 8844     北海道   根室振興局     目梨郡     羅臼町      1694
# 8845     北海道   根室振興局     目梨郡     羅臼町      1694
# 8846     北海道   根室振興局     目梨郡     羅臼町      1694
# 8847     北海道   根室振興局     目梨郡     羅臼町      1694
# 8848     北海道   根室振興局     目梨郡     羅臼町      1694
#
#                                                geometry  HYOSYO CITYNAME NAME
# 0     POLYGON ((141.34233 43.06682, 141.34285 43.066...       1   札幌市中央区  NaN  \
# 1     POLYGON ((141.40839 43.18395, 141.40833 43.183...       1    札幌市北区  NaN
# 2     POLYGON ((141.44707 43.15616, 141.44694 43.155...       1    札幌市東区  NaN
# 3     POLYGON ((141.46244 43.10010, 141.46265 43.100...       1   札幌市白石区  NaN
# ...

# %%
hokkaido_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8849 entries, 0 to 8848
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   8849 non-null   object
#  1   N03_002   8849 non-null   object
#  2   N03_003   6415 non-null   object
#  3   N03_004   8849 non-null   object
#  4   KEY_CODE  8849 non-null   int64
#  5   geometry  8849 non-null   geometry
#  6   HYOSYO    8849 non-null   int64
#  7   CITYNAME  8849 non-null   object
#  8   NAME      0 non-null      object
#  9   HTKSYORI  8849 non-null   int64
#  10  HTKSAKI   0 non-null      float64
#  11  GASSAN    0 non-null      float64
#  12  人口総数      8849 non-null   object
#  13  男         8849 non-null   object
#  14  女         8849 non-null   object
#  15  世帯総数      8849 non-null   object
# dtypes: float64(2), geometry(1), int64(3), object(10)
# memory usage: 1.1+ MB

# %%
hokkaido_pop['人口総数'] = hokkaido_pop['人口総数'].astype(int)

# %%
hokkaido_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8849 entries, 0 to 8848
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   8849 non-null   object
#  1   N03_002   8849 non-null   object
#  2   N03_003   6415 non-null   object
#  3   N03_004   8849 non-null   object
#  4   KEY_CODE  8849 non-null   int64
#  5   geometry  8849 non-null   geometry
#  6   HYOSYO    8849 non-null   int64
#  7   CITYNAME  8849 non-null   object
#  8   NAME      0 non-null      object
#  9   HTKSYORI  8849 non-null   int64
#  10  HTKSAKI   0 non-null      float64
#  11  GASSAN    0 non-null      float64
#  12  人口総数      8849 non-null   int64
#  13  男         8849 non-null   object
#  14  女         8849 non-null   object
#  15  世帯総数      8849 non-null   object
# dtypes: float64(2), geometry(1), int64(4), object(9)
# memory usage: 1.1+ MB

# %%
hokkaido_pop.plot(column='人口総数',legend=True)
# Out:
# <Axes: >

# %% [markdown]
# This assignment was much easier than what we did last week. I am actually starting enjoying gis.
